# %%
# %pip install pandas

# %%
import pandas as pd

# %%
data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 28, 22],
        'City': ['New York', 'San Francisco', 'Seattle']}
 
df = pd.DataFrame(data)

# %%
print(df)

# %%
names = df['Name']

# %%
names

# %%
subset = df[1:3]
print(subset)

# %%
df['salary'] = [2000,30000,21000]
print (df)

# %%
youngsters = df[df['Age']>22]
print(youngsters)

# %%
# Creating a DataFrame
data = {'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
        'Value': [10, 15, 20, 25, 30, 35]}
 
df = pd.DataFrame(data)
 
# Grouping by 'Category'
grouped = df.groupby('Category')
#print(grouped)
sum_values = grouped['Value'].sum()
#print(sum_values)
max_values = grouped['Value'].max()
min_values = grouped['Value'].min()
count_values = grouped['Value'].count()
print(count_values)

# %%
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 22, 34, 29],
        'City': ['New York', 'Paris', 'Berlin', 'London']}
df = pd.DataFrame(data)

# %%
# %pip uninstall streamlit
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#   Cell In[8], line 1
#     streamlit hello
#               ^
# SyntaxError: invalid syntax

# %%
import os
import pandas as pd

LOCAL_FILE_FOLDER='C:/Users/gbandaru/python_new_project/source/'

for entry in os.scandir(LOCAL_FILE_FOLDER):
    if entry.is_file() and entry.name.endswith('xlsx'):
        print(entry.path)
        read_file = pd.read_excel(entry.path,engine='openpyxl')
        #basename ='C:/Users/gbandaru/python_new_project/target/'+(os.path.basename(entry.path)).split('.')[0]+'.csv'
        #read_file.to_csv (basename,index = None,header=True,quotechar='"',doublequote=True)

# %%
import os
import pandas as pd

LOCAL_FILE_FOLDER='C:/Users/gbandaru/python_new_project/source/'

for entry in os.scandir(LOCAL_FILE_FOLDER):
    if entry.is_file() and entry.name.endswith('xlsx'):
        print(entry.path)
        read_file = pd.read_excel(entry.path,engine='openpyxl')
        basename ='C:/Users/gbandaru/python_new_project/target/'+(os.path.basename(entry.path)).split('.')[0]+'.csv'
        read_file.to_csv (basename,index = None,header=True,quotechar='"',doublequote=True)
print((os.path.basename(entry.path)).split('.')[0]+'.csv')

# %%
import os
print()

# %%
from zipfile import ZipFile
zip_path = 'C:/Users/gbandaru/python_new_project/source/csv_file.zip'
file_to_zip = './target/Violations_be_deleted.csv'
with ZipFile(zip_path,'w') as zip:
  zip.write(file_to_zip)

# %%
import pandas as pd
df=pd.read_csv("./source/Stackline_inhouse_share.csv")
print(df.head(1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("./source/Stackline_inhouse_share.csv")
#       3 print(df.head(1))
#
# ...
